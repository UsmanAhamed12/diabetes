# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
from sklearn.datasets import load_diabetes

# %%
diabetes = load_diabetes()

# %%
dir(diabetes)
# Out:
# ['DESCR',
#  'data',
#  'data_filename',
#  'data_module',
#  'feature_names',
#  'frame',
#  'target',
#  'target_filename']

# %%
print(diabetes['DESCR'])
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
# :Number of Instances: 442
#
# :Number of Attributes: First 10 columns are numeric predictive values
#
# :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
# :Attribute Information:
#     - age     age in years
#     - sex
#     - bmi     body mass index
#     - bp      average blood pressure
#     - s1      tc, total serum cholesterol
#     - s2      ldl, low-density lipoproteins
#     - s3      hdl, high-density lipoproteins
#     - s4      tch, total cholesterol / HDL
#     - s5      ltg, possibly log of serum triglycerides level
# ...

# %%
diabetes['data']
# Out:
# array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990749, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06833155, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286131, -0.02593034],
#        ...,
#        [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#         -0.04688253,  0.01549073],
#        [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#          0.04452873, -0.02593034],
#        [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.00422151,  0.00306441]], shape=(442, 10))

# %%
diabetes['target']
# Out:
# array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#         69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#         68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#         87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
#        259.,  53., 190., 142.,  75., 142., 155., 225.,  59., 104., 182.,
#        128.,  52.,  37., 170., 170.,  61., 144.,  52., 128.,  71., 163.,
#        150.,  97., 160., 178.,  48., 270., 202., 111.,  85.,  42., 170.,
#        200., 252., 113., 143.,  51.,  52., 210.,  65., 141.,  55., 134.,
#         42., 111.,  98., 164.,  48.,  96.,  90., 162., 150., 279.,  92.,
#         83., 128., 102., 302., 198.,  95.,  53., 134., 144., 232.,  81.,
#        104.,  59., 246., 297., 258., 229., 275., 281., 179., 200., 200.,
#        173., 180.,  84., 121., 161.,  99., 109., 115., 268., 274., 158.,
#        107.,  83., 103., 272.,  85., 280., 336., 281., 118., 317., 235.,
# ...

# %%
diabetes['feature_names']
# Out:
# ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']

# %% [markdown]
# ## Preparing The Dateset

# %%
Data = pd.DataFrame(diabetes['data'], columns= diabetes['feature_names'])
Data.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019907 -0.017646
# 1 -0.039493 -0.068332 -0.092204
# 2 -0.002592  0.002861 -0.025930
# 3  0.034309  0.022688 -0.009362
# 4 -0.002592 -0.031988 -0.046641

# %%
Data['target'] = diabetes['target']
Data.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6  target
# 0 -0.002592  0.019907 -0.017646   151.0
# 1 -0.039493 -0.068332 -0.092204    75.0
# 2 -0.002592  0.002861 -0.025930   141.0
# 3  0.034309  0.022688 -0.009362   206.0
# 4 -0.002592 -0.031988 -0.046641   135.0

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     442 non-null    float64
#  1   sex     442 non-null    float64
#  2   bmi     442 non-null    float64
#  3   bp      442 non-null    float64
#  4   s1      442 non-null    float64
#  5   s2      442 non-null    float64
#  6   s3      442 non-null    float64
#  7   s4      442 non-null    float64
#  8   s5      442 non-null    float64
#  9   s6      442 non-null    float64
#  10  target  442 non-null    float64
# dtypes: float64(11)
# memory usage: 38.1 KB

# %%
for feature in Data.columns:
    print(f'{feature} has {len(Data[feature].unique())} unique lables')
# Out:
# age has 58 unique lables
# sex has 2 unique lables
# bmi has 163 unique lables
# bp has 100 unique lables
# s1 has 141 unique lables
# s2 has 302 unique lables
# s3 has 63 unique lables
# s4 has 66 unique lables
# s5 has 184 unique lables
# s6 has 56 unique lables
# target has 214 unique lables

# %%
## Summarizing the stats of the data
Data.describe().T
# Out:
#         count          mean        std        min        25%         50%  \
# age     442.0 -2.511817e-19   0.047619  -0.107226  -0.037299    0.005383
# sex     442.0  1.230790e-17   0.047619  -0.044642  -0.044642   -0.044642
# bmi     442.0 -2.245564e-16   0.047619  -0.090275  -0.034229   -0.007284
# bp      442.0 -4.797570e-17   0.047619  -0.112399  -0.036656   -0.005670
# s1      442.0 -1.381499e-17   0.047619  -0.126781  -0.034248   -0.004321
# s2      442.0  3.918434e-17   0.047619  -0.115613  -0.030358   -0.003819
# s3      442.0 -5.777179e-18   0.047619  -0.102307  -0.035117   -0.006584
# s4      442.0 -9.042540e-18   0.047619  -0.076395  -0.039493   -0.002592
# s5      442.0  9.293722e-17   0.047619  -0.126097  -0.033246   -0.001947
# s6      442.0  1.130318e-17   0.047619  -0.137767  -0.033179   -0.001078
# target  442.0  1.521335e+02  77.093005  25.000000  87.000000  140.500000
#
#                75%         max
# age       0.038076    0.110727
# ...

# %%
## Check the missing values
Data.isnull().sum()
# Out:
# age       0
# sex       0
# bmi       0
# bp        0
# s1        0
# s2        0
# s3        0
# s4        0
# s5        0
# s6        0
# target    0
# dtype: int64

# %%
## Exploratrry Data Analysis

import seaborn as sns
sns.heatmap(Data.corr(), annot= True)
plt.show()

# %%
sns.scatterplot(x = Data['bmi'], y = Data['target'], data= Data)
plt.show()

# %%
sns.regplot(x = Data['bmi'], y = Data['target'], data= Data)
plt.show()

# %%
sns.regplot(x = Data['s5'], y = Data['target'], data= Data)
plt.show()

# %%
for feature in Data.columns.drop('target'):
    sns.regplot(x = Data[feature], y = Data['target'], data= Data)
    
    plt.show()

# %%
X = Data.drop('target', axis= 1)
X.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019907 -0.017646
# 1 -0.039493 -0.068332 -0.092204
# 2 -0.002592  0.002861 -0.025930
# 3  0.034309  0.022688 -0.009362
# 4 -0.002592 -0.031988 -0.046641

# %%
y = Data.iloc[:,-1]

# %%
## Train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size= 0.3, random_state= 42)

# %%
## standadize the dataset
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
import pickle 
pickle.dump(scaler, open('scalling.pkl', 'wb'))

# %%
X_train
# Out:
# array([[ 6.42054387e-01,  1.05661647e+00,  6.19059528e-01, ...,
#          6.76301514e-01,  1.27560982e+00, -2.79646760e-04],
#        [ 1.58492079e+00, -9.46417203e-01,  1.71984406e+00, ...,
#         -8.48887236e-02,  8.94884476e-02,  1.72793733e+00],
#        [-1.24367842e+00,  1.05661647e+00, -2.79540092e-01, ...,
#          6.76301514e-01,  3.90205997e-01,  1.12306139e+00],
#        ...,
#        [ 6.42054387e-01, -9.46417203e-01, -4.81725006e-01, ...,
#         -8.46078961e-01, -2.67756388e-01, -8.66904956e-02],
#        [-3.00812016e-01, -9.46417203e-01, -5.49119978e-01, ...,
#         -8.48887236e-02, -8.43116611e-01, -8.64388135e-01],
#        [-2.02940042e+00, -9.46417203e-01,  5.29199566e-01, ...,
#         -8.46078961e-01, -1.47469368e-01, -8.66904956e-02]],
#       shape=(309, 10))

# %%
X_test
# Out:
# array([[ 9.56343188e-01, -9.46417203e-01, -1.89680130e-01, ...,
#          6.76301514e-01,  6.37060846e-01, -1.73101344e-01],
#        [ 1.97778179e+00, -9.46417203e-01,  7.08919490e-01, ...,
#         -8.46078961e-01, -5.10233703e-01, -5.18744740e-01],
#        [ 1.34920419e+00,  1.05661647e+00, -1.44750149e-01, ...,
#         -8.48887236e-02,  1.72402156e+00, -4.32333891e-01],
#        ...,
#        [ 1.34920419e+00,  1.05661647e+00, -9.98201681e-02, ...,
#          3.33765907e-01, -7.87921617e-01, -2.79646760e-04],
#        [ 3.27765586e-01, -9.46417203e-01, -9.98419788e-01, ...,
#         -1.60726920e+00, -9.28954342e-01,  7.77417992e-01],
#        [ 4.06337786e-01,  1.05661647e+00,  8.88639413e-01, ...,
#          5.24063466e-01,  9.12084175e-01,  7.77417992e-01]],
#       shape=(133, 10))

# %% [markdown]
# ## Model Training

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
## print the coffeciatn
model.coef_
# Out:
# array([  1.35246724, -12.45426893,  26.21004615,  18.61443344,
#        -43.26039442,  24.2556288 ,   5.73862584,  13.96342685,
#         31.57521526,   1.98339354])

# %%
model.intercept_
# Out:
# np.float64(153.90291262135923)

# %%
## On which parameters the model has been trained 
model.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
## prediction with test data
pred= model.predict(X_test)

# %%
model.score(X_test, y_test)
# Out:
# 0.4772897164322618

# %%
## plot a scatter plot for the prediction
plt.scatter(y_test, pred)
plt.show()

# %%
## Residels
residuls = y_test - pred
residuls
# Out:
# 287     80.530300
# 211   -111.100523
# 72      76.655991
# 321    -62.759773
# 73     -12.883053
#           ...
# 238     54.002213
# 26      44.898996
# 7      -59.288768
# 401     12.191330
# 108     -1.218705
# Name: target, Length: 133, dtype: float64

# %%
sns.displot(residuls, kind= 'kde')
plt.show()

# %%
## Scatter plot respect to residuls
plt.scatter(pred, residuls)
plt.show()

# %%
from sklearn.metrics import mean_squared_error, median_absolute_error

print(median_absolute_error(y_test, pred))
print(mean_squared_error(y_test, pred))
print(mean_squared_error(y_test, pred) ** 0.5)
print(np.sqrt(mean_squared_error(y_test, pred)))
# Out:
# 37.339199919338
# 2821.7509810013103
# 53.1201560709427
# 53.1201560709427

# %% [markdown]
# ## R Square and Adjusted R Squared

# %%
from sklearn.metrics import r2_score
score = r2_score(y_test, pred)
score
# Out:
# 0.4772897164322618

# %%
diabetes.data[0].reshape(1,-1)
# Out:
# array([[ 0.03807591,  0.05068012,  0.06169621,  0.02187239, -0.0442235 ,
#         -0.03482076, -0.04340085, -0.00259226,  0.01990749, -0.01764613]])

# %%
### transformation of new data

scaler.transform([diabetes['data'][0]])
# Out:
# /Users/inazawaelectronics/Documents/endtoend ML project/diabetes/newenv/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[ 0.79919879,  1.05661647,  1.22561427,  0.43017104, -0.95450252,
#         -0.74962288, -0.90442588, -0.08488872,  0.37555077, -0.43233389]])

# %%
model.predict([diabetes['data'][0]])
# Out:
# array([156.72428006])

# %%
model.predict(scaler.transform([diabetes['data'][0]]))
# Out:
# /Users/inazawaelectronics/Documents/endtoend ML project/diabetes/newenv/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([209.68990406])

# %%
import pickle

# %%
pickle.dump(model, open('regression_model.pkl', 'wb'))

# %%
pickle_model = pickle.load(open('regression_model.pkl', 'rb'))

# %%
pickle_model.predict(scaler.transform([diabetes['data'][0]]))
# Out:
# /Users/inazawaelectronics/Documents/endtoend ML project/diabetes/newenv/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([209.68990406])
